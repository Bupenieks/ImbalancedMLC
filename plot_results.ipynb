# %%
from PIL import Image
from matplotlib import pyplot as plt
import json

# %%
# !ls Baseline/baseline_model_low_LR
# Out:
# batch_times.txt  model.png   model_10.h5  model_4.h5  model_7.h5
# info.txt	 model_0.h5  model_2.h5   model_5.h5  model_8.h5
# logs.json	 model_1.h5  model_3.h5   model_6.h5  model_9.h5

# %%
data = dict()
with open('Baseline/baseline_model_low_LR/logs.json' ,'r') as d:
    data = json.load(d)
    
for key in data:
    if 'loss' in key:
        print key
        plt.plot(data[key])
        plt.show()
# Out:
# val_pottedplant_output_loss
# horse_output_loss
# val_loss
# car_output_loss
# loss
# val_bicycle_output_loss
# bicycle_output_loss
# motorbike_output_loss
# val_sheep_output_loss
# val_bird_output_loss
# val_aeroplane_output_loss
# chair_output_loss
# cow_output_loss
# val_chair_output_loss
# tvmonitor_output_loss
# train_output_loss
# val_dog_output_loss
# val_car_output_loss
# aeroplane_output_loss
# bird_output_loss
# dog_output_loss
# val_diningtable_output_loss
# bottle_output_loss
# val_bottle_output_loss
# val_motorbike_output_loss
# val_train_output_loss
# val_person_output_loss
# val_bus_output_loss
# bus_output_loss
# val_horse_output_loss
# person_output_loss
# val_cow_output_loss
# diningtable_output_loss
# cat_output_loss
# val_cat_output_loss
# sheep_output_loss
# val_tvmonitor_output_loss
# sofa_output_loss
# pottedplant_output_loss
# boat_output_loss
# val_sofa_output_loss
# val_boat_output_loss
